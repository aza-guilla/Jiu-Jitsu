# %%
answer = input("Who's ready to grapple? (Me/Not me) ")

if answer.lower().strip() == "me":      #.lower converts anything typed to lowercase, .strip takes out white spaces
    answer = input('''Your opponent stands before you. Your eyes meet. What do you do? (Enter the letter only, no period)
    
    A. Shake hands
    B. Embrace him
    C. Slap -> bump
    D. Wink, then hit the shower
    
    ''')
    if answer.lower().strip() == "c":
        answer = input('''You gently slap hands and bump fists, and the game has begun. 
    Your opponent immediately drops into a staggered stance. You note his gnarled ears
    and the fact that he is wearing a t-shirt tucked into athletic shorts. What is your next move?
    (Enter the letter only, no period)
    
    A. Arm drag to double leg
    B. Quickly make your grips and pull guard 
    
        ''')
        if answer.lower().strip() == "b":
            answer = input('''Your wrestling has humiliated you for the last time. 
    You make the right call by tying up and immediately jumping to closed guard. 
    Your opponent grunts his displeasure with your strategy, which probably means you've done something right. 
    He immediately buries his head in your chest. What do you do? (Enter the letter only, no period)
    
    A. Push his head off your center line and wrap up a guillotine
    B. Keeping his posture broken with head and arm grips, open your guard and place your feet on his hips
    
    ''')
            if answer.lower().strip() == "a":
                print('''You wrap up a tight guillotine and he taps! You've won this round...unfortunately, 
    there are four minutes left on the clock and the round restarts on the feet. Good luck!''')            
            elif answer.lower().strip() == "b":
                print('''Feeling saucy, you open your guard to start attacking. Unfortunately, as soon as you do, your
    opponent pushes away from your feeble guard, makes space, and quickly passes to the left. As he wraps your
    head with an iron grip, you are left to ponder your ineffective strategy for the remainder of the round. 
    Game over''')
            else:
                print("Porra! Invalid response. Start over!")
        elif answer.lower().strip() == "a":
            print('''Oh dear. You've vastly overestimated your wrestling ability again, and your opponent
    makes this clear by re-dragging to your back and suplexing you into the mat. You're not injured, 
    but everyone watching was like "OHHHHHHHHHHHHH!" Your coach can do nothing but 
    sigh his disapproval as you spend the rest of the round struggling unsuccessfully to get your guard back. 
    Game over''')
        else:
            print("Porra! Invalid response. Start over!")
            
    else:
        print("You made it weird...game over")
else:
    print("Porra! Invalid response. Start over!")
# Out:
# Who's ready to grapple? (Me/Not me) me
# Your opponent stands before you. Your eyes meet. What do you do? (Enter the letter only, no period)
#
#     A. Shake hands
#     B. Embrace him
#     C. Slap -> bump
#     D. Wink, then hit the shower
#
#     c
# You gently slap hands and bump fists, and the game has begun.
#     Your opponent immediately drops into a staggered stance. You note his gnarled ears
#     and the fact that he is wearing a t-shirt tucked into athletic shorts. What is your next move?
#     (Enter the letter only, no period)
#
#     A. Arm drag to double leg
#     B. Quickly make your grips and pull guard
#
#         b
# Your wrestling has humiliated you for the last time.
#     You make the right call by tying up and immediately jumping to closed guard.
#     Your opponent grunts his displeasure with your strategy, which probably means you've done something right.
#     He immediately buries his head in your chest. What do you do? (Enter the letter only, no period)
# ...
